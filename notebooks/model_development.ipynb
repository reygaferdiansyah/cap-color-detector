# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# Model Development & Experimentation\n",
        "\n",
        "## Approach\n",
        "- Using YOLOv11 & YOLOv12 (6 variants)\n",
        "- Dataset from Roboflow (3 bottle cap classes)\n",
        "- Heavy augmentation + AdamW + label smoothing\n",
        "- Training 250 epochs with patience=40\n",
        "\n",
        "## Results Summary\n",
        "| Model      | mAP@0.5 | Size  | FPS (GPU) |\n",
        "|------------|---------|-------|-----------|\n",
        "| YOLOv12n   | ~0.92   | 4MB   | 180+      |\n",
        "| YOLOv12m   | ~0.96   | 28MB  | 90+       |\n",
        "\n",
        "## Insights\n",
        "- 'Others' class is dominant -> needs class weighting or focal loss\n",
        "- Poor lighting -> misclassification of Dark-Blue as Others\n",
        "- YOLOv12 > YOLOv11 across all sizes\n",
        "\n",
        "-> Best model: **YOLOv12m** (final_v12_medium)"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python 3",
      "language": "python",
      "name": "python3"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 2
}
